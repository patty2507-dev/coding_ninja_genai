# %%
from langchain_community.document_loaders import TextLoader,PyPDFLoader,CSVLoader

loader = TextLoader("./sample_docs/personal_loan.txt")
documents = loader.load()

# %%
# documents
loader = PyPDFLoader("bajaj_finance_policy_reference.pdf")
documents = loader.load()

# %%
# print(documents[0].page_content)

# %%
documents[4].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-05-11T14:01:35+00:00',
#  'author': 'Bajaj Finance Limited',
#  'keywords': '',
#  'moddate': '2026-05-11T14:01:35+00:00',
#  'subject': 'Internal Policy Manual FY 2024-25',
#  'title': 'Bajaj Finance Policy Reference Document',
#  'trapped': '/False',
#  'source': 'bajaj_finance_policy_reference.pdf',
#  'total_pages': 12,
#  'page': 4,
#  'page_label': '5'}

# %%
documents[4].page_content[:500]
# Out:
# 'BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 5\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 03\nHome Loan — Eligibility & Terms\n3.1 Loan Parameters\nLoan Amount\n■5 lakhs – ■5 crores | Subject to LTV and eligibility\nTenure\n5 – 30 years | Maximum age at loan maturity: 70 years\nInterest Type\nFloating rate linked to Repo Rate | Fixed rate available for first 3 years\nFloating Rate\nREPO + 2.0% to REPO + 3.5% de'

# %%
import csv
csv_data = [
    ['customer_id', 'name',         'loan_type', 'emi',  'status'],
    ['BF001',       'Amit Sharma',  'Personal',  '8400', 'Active'],
    ['BF002',       'Priya Patel',  'Gold',      '5200', 'Active'],
    ['BF003',       'Rajan Mehta',  'Home',      '22000','Default'],
    ['BF004',       'Sunita Rao',   'Business',  '15000','Active'],
]

with open('./sample_docs/customers.csv', 'w', newline='') as f:
    csv.writer(f).writerows(csv_data)

# %%
loader = CSVLoader("./sample_docs/customers.csv")
documents = loader.load()

# %%
documents[0].page_content[:500]
# Out:
# 'customer_id: BF001\nname: Amit Sharma\nloan_type: Personal\nemi: 8400\nstatus: Active'
