# %%
policy_text = """Bajaj Finance personal loan interest rate starts at 12% per annum.
Processing fee is 2% of the loan amount. EMI bounce attracts a
Rs.500 penalty charge. Prepayment charges are 4% of the outstanding
principal, waived after 12 EMIs.Eligibility: Age 21-60 years. Minimum income Rs 25,000 per month.
CIBIL score 700 and above for standard approval.
FOIR maximum 50 percent of monthly income.
"""

# %%
policy_text[0:50]
# Out:
# 'Bajaj Finance personal loan interest rate starts a'

# %%
len(policy_text)
# Out:
# 388

# %%
#
chunks = []
start = 0
chunk_size = 100

while start < len(policy_text):
    end = start + chunk_size
    chunks.append(policy_text[start:end])
    start = end

chunks
# Out:
# ['Bajaj Finance personal loan interest rate starts at 12% per annum.\nProcessing fee is 2% of the loan ',
#  'amount. EMI bounce attracts a\nRs.500 penalty charge. Prepayment charges are 4% of the outstanding\npr',
#  'incipal, waived after 12 EMIs.Eligibility: Age 21-60 years. Minimum income Rs 25,000 per month.\nCIBI',
#  'L score 700 and above for standard approval.\nFOIR maximum 50 percent of monthly income.\n']

# %%
len(chunks[0])
# Out:
# 100

# %%
# policy_text.split()
words = policy_text.split()
chunks = []
current_chunk = []
current_len = 0

for word in words:
    word_len = len(word) + 1  # +1 for the space
    if current_len + word_len > chunk_size:
        chunks.append(" ".join(current_chunk))
        current_chunk = [word]
        current_len = word_len
    else:
        current_chunk.append(word)
        current_len += word_len

if current_chunk:
    chunks.append(" ".join(current_chunk))

# %%
chunks
# Out:
# ['Bajaj Finance personal loan interest rate starts at 12% per annum. Processing fee is 2% of the loan',
#  'amount. EMI bounce attracts a Rs.500 penalty charge. Prepayment charges are 4% of the outstanding',
#  'principal, waived after 12 EMIs.Eligibility: Age 21-60 years. Minimum income Rs 25,000 per month.',
#  'CIBIL score 700 and above for standard approval. FOIR maximum 50 percent of monthly income.']

# %%
print(policy_text)
# Out:
# Bajaj Finance personal loan interest rate starts at 12% per annum.
# Processing fee is 2% of the loan amount. EMI bounce attracts a
# Rs.500 penalty charge. Prepayment charges are 4% of the outstanding
# principal, waived after 12 EMIs.Eligibility: Age 21-60 years. Minimum income Rs 25,000 per month.
# CIBIL score 700 and above for standard approval.
# FOIR maximum 50 percent of monthly income.

# %%
# overlap

from langchain_text_splitters import CharacterTextSplitter,RecursiveCharacterTextSplitter

splitter = CharacterTextSplitter(
    separator=".",
    chunk_size=30,
    chunk_overlap=10
)


# separator = "\n\n"   # split by paragraph
# separator = "\n"     # split by line
# separator = " "      # split by word space
# separator = "."      # split by sentence end
# separator = ","      # split by comma
# separator = ""       # split by character

chunks = splitter.split_text(policy_text)
# Out:
# Created a chunk of size 65, which is longer than the specified 30
# Created a chunk of size 40, which is longer than the specified 30
# Created a chunk of size 77, which is longer than the specified 30
# Created a chunk of size 35, which is longer than the specified 30
# Created a chunk of size 48, which is longer than the specified 30
# Created a chunk of size 42, which is longer than the specified 30

# %%
print(chunks)
# Out:
# ['Bajaj Finance personal loan interest rate starts at 12% per annum', 'Processing fee is 2% of the loan amount', 'EMI bounce attracts a\nRs', '500 penalty charge', 'Prepayment charges are 4% of the outstanding\nprincipal, waived after 12 EMIs', 'Eligibility: Age 21-60 years', 'Minimum income Rs 25,000 per month', 'CIBIL score 700 and above for standard approval', 'FOIR maximum 50 percent of monthly income']

# %%
len(chunks)
# Out:
# 9

# %%
chunks
# Out:
# ['Bajaj Finance personal loan interest rate starts at 12% per annum',
#  'Processing fee is 2% of the loan amount',
#  'EMI bounce attracts a\nRs',
#  '500 penalty charge',
#  'Prepayment charges are 4% of the outstanding\nprincipal, waived after 12 EMIs',
#  'Eligibility: Age 21-60 years',
#  'Minimum income Rs 25,000 per month',
#  'CIBIL score 700 and above for standard approval',
#  'FOIR maximum 50 percent of monthly income']

# %%
# len(chunks[)

# %%
splitter = RecursiveCharacterTextSplitter(
    separators=["\n\n", "\n", " ", ".", ","],
    chunk_size=30,
    chunk_overlap=10
)

chunks = splitter.split_text(policy_text)

len(chunks)
# Out:
# 19

# %%
# policy_text
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

pdf_path = "bajaj_finance_policy_reference.pdf"
loader = PyPDFLoader(pdf_path)
raw_docs = loader.load()

# %%
len(raw_docs[0].page_content)
# Out:
# 1153

# %%
raw_docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 1\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n BAJAJ FINANCE LIMITED\n Policy & Procedure Reference\n Document\n Helpdesk Agent Knowledge Base\n FY 2024–25 | All Loan Products\nDocument Type\nInternal Policy & Procedure Manual\nCoverage\nPersonal Loan · Home Loan · Gold Loan · Business Loan · CIBIL Policy\nIntended Users\nHelpdesk Agents · Branch Executives · Collections Team · Sales Team\nClassification\nCONFIDENTIAL — For Internal Use Only\nVersion\nv3.2 — Revised April 2024\nApproved by\nVP Operations & Chief Risk Officer\nNext Review\nOctober 2024\nDocument Sections\n #\n Section\n Ref\n01\n Personal Loan — Eligibility & Rates\n Page 2\n02\n Personal Loan — Required Documents\n Page 3\n03\n Home Loan — Eligibility & Terms\n Page 4\n04\n Loan Rejection & Reapplication Policy\n Page 5\n05\n EMI Payment & Default Policy\n Page 6\n06\n Business Loan — SME & MSME Products\n Page 7\n07\n Gold Loan — Products & Process\n Page 8\n08\n CIBIL Score — Impact & Reporting\n Page 9\n09\n Customer Grievance Redressal Policy\n Page 10\n10\n Loan Renewal Policy\n Page 11'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 2\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 01\nPersonal Loan — Eligibility Criteria & Interest Rates\n1.1 Eligibility Criteria\nBajaj Finance personal loans are available to salaried and self-employed professionals meeting the following criteria.\nAll conditions must be satisfied simultaneously — partial eligibility does not qualify for approval.\nAge\n21 – 60 years for salaried | 25 – 65 years for self-employed\nMinimum Income\n■25,000/month net take-home (salaried) | ■4.8 lakhs annual ITR (self-employed)\nCIBIL Score\n700 and above for standard approval | 650–699 subject to enhanced scrutiny\nEmployment\nMinimum 1 year current employer | 2 years total work experience\nFOIR Limit\nMaximum 50% Fixed Obligation to Income Ratio including proposed EMI\nSelf-Employed\nMinimum 3 years in same profession | Doctors, CAs, Architects eligible\nGovt/Defence\nRelaxed FOIR up to 55% | Age limit extended to 65 years\n1.2 Interest Rate Slabs\nInterest rates are risk-based and determined by CIBIL score, employment category, and loan amount. Rates effective\nApril 2024.\nCIBIL Score\n Category\n Interest Rate (p.a.)\n Max Loan Amount\n Tenure\n750 and\nabove\n Salaried\n 11.00% – 13.00%\n Up to ■40 lakhs\n 12 – 84 months\n750 and\nabove\n Self-Employed\n 12.00% – 14.00%\n Up to ■25 lakhs\n 12 – 60 months\n700 – 749\n Salaried\n 13.00% – 16.00%\n Up to ■25 lakhs\n 12 – 60 months\n700 – 749\n Self-Employed\n 14.00% – 17.50%\n Up to ■15 lakhs\n 12 – 48 months\n650 – 699\n Salaried\n 16.00% – 20.00%\n Up to ■10 lakhs\n 12 – 36 months\nBelow 650\n All\n Not eligible\n —\n —\n1.3 Fees & Charges\nProcessing Fee\n1.5% – 3.5% of loan amount + GST | Minimum ■1,999\nLate Payment Penalty\n2% per month on overdue EMI amount | Applied from day 1 of default\nEMI Bounce Charge\n■1,000 + GST per bounced NACH/ECS mandate\nPrepayment (Full)\n4% of outstanding principal if closed within 12 months | 2% thereafter\nPart Prepayment\nAllowed after 12 months | 2% charge on prepaid amount | Max 25% of principal per year\nLoan Cancellation\nWithin 15 days of disbursal — processing fee non-refundable\nDuplicate NOC\n■500 + GST per request | Issued within 7 working days\nForeclosure Statement\n■200 + GST | Available within 2 working days'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 3\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\nAGENT NOTE: Always check FOIR before quoting eligibility. A customer with CIBIL 760 and monthly income\n■30,000 but existing EMIs of ■18,000 exceeds FOIR (60%) and is INELIGIBLE for a new loan despite good\nCIBIL score.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 4\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 02\nPersonal Loan — Required Documents\n2.1 Identity & Address Proof\nIdentity Proof\nAadhaar Card (mandatory) | PAN Card (mandatory) | Passport / Voter ID (any one)\nAddress Proof\nAadhaar Card | Utility Bill (< 3 months) | Bank Statement (< 3 months)\nPhoto\n2 recent passport size photographs | Digital photo acceptable via app\n2.2 Income Documents — Salaried Employees\nLast 3 salary slips\nEmployer stamp mandatory | PDF from company portal acceptable\nForm 16 (last 2 years)\nRequired for loan above ■10 lakhs | Both years mandatory\nBank statements (6\nmonths)\nPrimary salary account | All pages required | No missing months\nEmployment letter\nRequired if < 1 year with current employer\nOffer letter\nRequired if joining date < 6 months\n2.3 Income Documents — Self-Employed Professionals\nITR with computation\n(2 years)\nCA certified | Filed on time | Clear income declaration\nBalance Sheet & P&L;\nLast 2 years | CA certified mandatory\nBank statements (12\nmonths)\nBusiness account | All pages | Statement from bank letterhead\nGST Returns (if\napplicable)\nLast 4 quarters | For turnover above ■40 lakhs\nProfessional certificate\nDoctors: MCI registration | CAs: ICAI certificate | Architects: COA\n2.4 Additional Documents — High Loan Amounts\nFor loan amounts above ■15 lakhs, the following additional documents are required in addition to standard\ndocuments:\n■15 – 25 lakhs\nLast 2 years ITR | 12-month bank statement | Existing loan statements\n■25 – 40 lakhs\nAll above + Investment proof (FDs, MFs, stocks) | Property documents if available\nAbove ■40 lakhs\nAll above + Networth certificate from CA | Interview with Branch Manager required\nAGENT NOTE: Incomplete documents are the #1 reason for loan delays — not rejection. Always collect ALL\ndocuments upfront before submitting the application. Missing a single bank statement month causes automatic\nhold.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 5\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 03\nHome Loan — Eligibility & Terms\n3.1 Loan Parameters\nLoan Amount\n■5 lakhs – ■5 crores | Subject to LTV and eligibility\nTenure\n5 – 30 years | Maximum age at loan maturity: 70 years\nInterest Type\nFloating rate linked to Repo Rate | Fixed rate available for first 3 years\nFloating Rate\nREPO + 2.0% to REPO + 3.5% depending on CIBIL and LTV\nProcessing Fee\n0.5% – 1.0% of loan amount + GST | Minimum ■5,000\nPrepayment\nNo charges for floating rate | 2% for fixed rate within lock-in period\n3.2 Loan-to-Value (LTV) Limits — RBI Mandated\nUp to ■30 lakhs\nMaximum 90% of property value\n■30 – 75 lakhs\nMaximum 80% of property value\nAbove ■75 lakhs\nMaximum 75% of property value\nUnder-construction\nDisbursed in stages linked to construction milestones | Max LTV same as above'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 5, 'page_label': '6'}, page_content="BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 6\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 04\nLoan Rejection & Reapplication Policy\n4.1 Primary Rejection Reasons\nCIBIL Score Below Threshold\nScore below 650 results in automatic system rejection. Score 650–699 goes to manual review with 40%\napproval rate.\nFOIR Exceeded\nIf total EMI obligations including proposed loan exceed 50% of net monthly income, application is rejected\nregardless of CIBIL.\nMultiple Enquiries\nMore than 3 hard enquiries in 6 months indicates credit-hungry behaviour. Results in rejection or enhanced\nscrutiny.\nEmployment Instability\nJob changes within 6 months of application or less than 1 year at current employer. Self-employed with less than\n3 years vintage.\nIncome Inconsistency\nBank credits inconsistent with declared salary. Irregular salary credits. Large unexplained withdrawals.\nDocumentation Mismatch\nName discrepancy across Aadhaar, PAN, and salary slips. Address mismatch. Expired documents.\nExisting Default History\nAny default in last 36 months. Settled accounts (written as 'Settled' not 'Closed') result in rejection.\n4.2 Reapplication Policy\nCIBIL rejection\n90 days minimum | Improve score first | Max 2 reapplications in 12 months\nFOIR rejection\nAfter existing loan closure or income increase | No minimum wait period\nDocumentation issue\nCan reapply immediately with corrected documents\nEmployment rejection\nAfter completing 1 year with current employer\nMultiple enquiries\n180 days from date of last rejected application"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 6, 'page_label': '7'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 7\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 05\nEMI Payment & Default Policy\n5.1 EMI Payment Process\nEMI Date\n5th of every month (standard) | 1st or 10th available on request\nPayment Method\nNACH mandate (auto-debit from registered bank account) — mandatory\nNACH Setup\nCompleted within 5 working days of loan disbursal | Customer signs mandate form\nBounce Charge\n■1,000 + GST per bounced mandate | Applied on T+1 of bounce date\nManual Payment\nOnline portal / branch / NEFT | Must be done before 5th to avoid late fee\nPart Payment\nAllowed via online portal only | Minimum ■5,000 | Reduces tenure by default\n5.2 Default Consequences & NPA Classification\n Default Status\n Action Taken\n1 EMI missed\n Reminder SMS + call | ■1,000 bounce charge | Late payment fee 2% p.m.\n2 EMIs missed\n Collections team contact | Account flagged in internal system | CIBIL reporting begins (30 DPD)\n3 EMIs missed\n Legal notice issued | Field visit by recovery agent | CIBIL: 60 DPD reported\n6 EMIs missed\n NPA classification | Legal proceedings initiated | Account moved to NPA bucket\n12+ EMIs missed\n Loan written off | Legal suit filed | Auction proceedings for secured loans\n5.3 EMI Holiday / Moratorium Policy\nEMI Holiday is available for customers facing temporary financial hardship. This is NOT a loan waiver — interest\ncontinues to accrue during the holiday period.\nEligibility\nMinimum 12 EMIs paid | No existing default | Documented financial hardship\nDuration\nMaximum 3 months per request | Maximum 2 requests per loan lifetime\nInterest\nInterest accrues at contracted rate during holiday | Added to outstanding principal\nImpact on Tenure\nTenure extended by holiday duration | Customer notified in writing\nApplication\nBranch visit mandatory | Documents required: termination letter / medical certificate'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 7, 'page_label': '8'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 8\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 06\nBusiness Loan — SME & MSME Products\n6.1 Loan Parameters\nLoan Amount\n■2 lakhs – ■50 lakhs (unsecured) | Up to ■2 crores (secured)\nTenure\n12 – 96 months (unsecured) | Up to 120 months (secured)\nInterest Rate\n14% – 24% p.a. based on CIBIL and business vintage\nCollateral\nNot required for amounts up to ■50 lakhs | Required above ■50 lakhs\nBusiness Types\nSole Proprietorship | Partnership | Private Limited | LLP | Public Limited\nAnnual Turnover\nMinimum ■40 lakhs (unsecured) | Minimum ■1 crore (secured)\nBusiness Vintage\nMinimum 3 years in profit | 5 years for manufacturing sector'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 8, 'page_label': '9'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 9\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 07\nGold Loan — Products & Process\n7.1 Product Parameters\nLoan Amount\n■5,000 – ■2 crores | Based on gold weight and purity\nGold Purity\n18 karat to 24 karat accepted | Minimum 18K for eligibility\nLTV Ratio\nMaximum 75% of gold market value (RBI mandated ceiling)\nTenure\n3 months to 24 months | Bullet repayment or monthly interest options\nInterest Rate\n9.5% – 18% p.a. | 9.5%–12% for high-value (above ■5 lakhs) | Monthly interest option available\nAppraisal Process\nIn-branch gold testing using XRF machine | Results in 15 minutes\nDisbursal Time\nSame day — within 30 minutes of appraisal and KYC completion\nGold Storage\nStored in bank-grade vault | Fully insured | 24/7 CCTV surveillance\n7.2 Foreclosure Policy\nGold loan foreclosure (early closure before tenure end) is governed by the following policy. Foreclosure is the most\ncommon query from gold loan customers.\nWithin 3 months of\ndisbursal\n2% foreclosure charge on outstanding principal + accrued interest\n3 – 6 months\n2% foreclosure charge on outstanding principal\n6 – 12 months\n1% foreclosure charge on outstanding principal\nAfter 12 months\nNO foreclosure charge | Customer pays only outstanding principal + interest\nClosure Process\nBranch visit mandatory | Original pledge receipt required | NOC issued within 30 minutes\nGold Return\nGold returned immediately after full payment confirmation | Customer signs receipt\n7.3 Auction Policy — Non-Repayment\nIf a customer fails to repay the gold loan or renew at maturity, Bajaj Finance initiates auction proceedings after\n30 days of notice. Written notice is sent 30 days before auction. Auction proceeds are used to recover\noutstanding principal, interest, and charges. Any surplus is returned to the customer within 7 working days of\nauction.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content="BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 10\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 08\nCIBIL Score — Impact & Reporting Policy\n8.1 Credit Bureaus — Reporting\nBureaus Reported to\nCIBIL (TransUnion) | Experian | Equifax | CRIF High Mark — all 4 bureaus\nReporting Frequency\nMonthly — on the 7th of every month for previous month's data\nReporting Scope\nLoan sanction | EMI payment history | Default | Closure | Settlement\nPositive Reporting\n+5 to +10 points per month for on-time EMI payments (varies by bureau)\nHard Enquiry\nTriggered on loan application | -5 to -10 points | Visible to all lenders for 24 months\nSoft Enquiry\nTriggered for internal checks | Does NOT affect CIBIL score\n8.2 Negative Impact on CIBIL Score\n Event\n CIBIL Impact\n30 DPD (30 days overdue)\n -30 to -50 points | Reported after 30 days of missed payment\n60 DPD\n -50 to -80 points | Escalation to collections team\n90 DPD\n -80 to -100 points | NPA classification\nSettlement\n -100 to -150 points | Account shows as 'Settled' (not 'Closed') for 7 years\nWrite-off\n -150 to -200 points | Legal action record | Remains for 7 years\nLoan Closure (full repaid)\n +20 to +40 points | Account shows 'Closed' | Positive long-term impact\n8.3 CIBIL Dispute Resolution\nDispute Filing\nCustomer raises dispute on CIBIL website (www.cibil.com) | Bajaj Finance notified within 3 days\nInvestigation\nBajaj Finance internal team reviews within 15 working days\nResolution\nCorrection reported to all 4 bureaus if dispute is valid | Customer notified in writing\nTimeline\nEnd-to-end resolution: 30-45 working days from filing\nAgent Role\nDo NOT promise specific score changes | Direct to CIBIL dispute portal | Log complaint in CRM"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 11\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 09\nCustomer Grievance Redressal Policy\n9.1 Complaint Channels\nHelpdesk (L1)\n1800-103-3535 (toll free) | 8:00 AM – 8:00 PM | Mon–Sat | Resolution: 3 working days\nEmail (L1)\ncustomercare@bajajfinserv.in | Acknowledge within 24 hours | Resolution: 5 working days\nBranch Visit (L1)\nAny Bajaj Finance branch | CRM ticket raised immediately | Resolution: 3 working days\nOnline Portal (L1)\nwww.bajajfinserv.in/contact | 24/7 ticket submission | Resolution: 5 working days\nEscalation (L2)\nIf L1 unsatisfied: nodalofficer@bajajfinserv.in | Resolution: 7 working days\nOmbudsman (L3)\nRBI Banking Ombudsman if L2 fails | After 30 days of unresolved complaint\n9.2 Common Service Requests & Timelines\nNOC (No Objection\nCertificate)\nIssued within 7 working days of full loan closure | Digital + physical copy\nLien Release\n7 working days for property loans | 1 working day for gold loans\nLoan Statement\nInstantly via app/portal | Branch: within 1 working day\nInterest Certificate\nFor tax purposes | Available on portal | Branch: 2 working days\nRepayment Schedule\nAvailable on portal immediately | Branch copy: 1 working day\nDuplicate NOC\n■500 + GST | 7 working days | Original NOC must have been issued'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-05-11T14:01:35+00:00', 'author': 'Bajaj Finance Limited', 'keywords': '', 'moddate': '2026-05-11T14:01:35+00:00', 'subject': 'Internal Policy Manual FY 2024-25', 'title': 'Bajaj Finance Policy Reference Document', 'trapped': '/False', 'source': 'bajaj_finance_policy_reference.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 12\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 10\nLoan Renewal Policy\n10.1 Personal Loan Renewal Eligibility\nLoan renewal (top-up on existing loan) is available to existing customers who meet all the following criteria. All\nconditions must be satisfied simultaneously.\nRepayment Score\nInternal repayment score above 700 | Based on payment history on current loan\nDefault History\nNo defaults in last 12 months | No bounce in last 6 months\nLocation\nAvailable for Tier 1 and Tier 2 cities only | Rural customers NOT eligible for renewal\nMinimum Tenure\nAt least 6 EMIs paid on existing loan before renewal application\nOutstanding\nMinimum 12 months remaining on existing loan OR renewal at closure\n10.2 Renewal Loan Amount Limits\nSalaried — Tier 1 city\nMaximum ■1,00,000 top-up above existing outstanding\nSalaried — Tier 2 city\nMaximum ■75,000 top-up above existing outstanding\nSelf-employed — Tier 1\ncity\nMaximum ■50,000 top-up above existing outstanding\nSelf-employed — Tier 2\ncity\nMaximum ■30,000 top-up above existing outstanding\nRural customers\nNot eligible for renewal | Eligible for fresh loan application only\n10.3 Gold Loan Renewal\nRenewal at Maturity\nGold appraised again | New LTV applied | New interest rate quoted\nPartial Renewal\nCustomer can repay partial amount and renew for balance | Minimum repayment 10% of principal\nRenewal Charges\n■500 + GST processing fee | Fresh KYC if original documents expired\nGold Re-appraisal\nMandatory for all renewals | Price as per current market rate on renewal date\nThis document covers 10 policy areas used in the BajajBot helpdesk chatbot demonstration. Content is realistic but synthesized for training\npurposes. For live production queries, always refer to the latest policy published on the internal intranet.')]

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=256,
    chunk_overlap=32,
    separators=["\n\n", "\n", ". ", " ", ""],
)

chunks = splitter.split_documents(raw_docs)

# %%
len(chunks )
# Out:
# 88

# %%
print(chunks[4].page_content)
# Out:
# Page 5
# 05
#  EMI Payment & Default Policy
#  Page 6
# 06
#  Business Loan — SME & MSME Products
#  Page 7
# 07
#  Gold Loan — Products & Process
#  Page 8
# 08
#  CIBIL Score — Impact & Reporting
#  Page 9
# 09
#  Customer Grievance Redressal Policy
#  Page 10
# 10

# %%
chunks[4].page_content
# Out:
# 'BAJAJ FINANCE LIMITED\nInternal Policy Reference Document — CONFIDENTIAL\nPage 5\nFor internal use only | Bajaj Finance Limited | FY 2024-25 | Unauthorised distribution prohibited\n SECTION 03\nHome Loan — Eligibility & Terms\n3.1 Loan Parameters\nLoan Amount\n■5 lakhs – ■5 crores | Subject to LTV and eligibility\nTenure\n5 – 30 years | Maximum age at loan maturity: 70 years\nInterest Type\nFloating rate linked to Repo Rate | Fixed rate available for first 3 years\nFloating Rate\nREPO + 2.0% to REPO + 3.5% depending on CIBIL and LTV\nProcessing Fee\n0.5% – 1.0% of loan amount + GST | Minimum ■5,000\nPrepayment\nNo charges for floating rate | 2% for fixed rate within lock-in period\n3.2 Loan-to-Value (LTV) Limits — RBI Mandated\nUp to ■30 lakhs\nMaximum 90% of property value\n■30 – 75 lakhs\nMaximum 80% of property value\nAbove ■75 lakhs\nMaximum 75% of property value\nUnder-construction\nDisbursed in stages linked to construction milestones | Max LTV same as above'
