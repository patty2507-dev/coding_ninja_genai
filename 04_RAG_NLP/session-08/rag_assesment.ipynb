# %%
bajajbot_outputs = [
    {
        'id': 'Q1',
        'question': 'What is the penalty for bouncing a personal loan EMI?',
        'answer': 'The EMI bounce charge for a personal loan is Rs.500 + GST per instance. '
                  'After 3 consecutive bounces, the loan may be classified as NPA.',
        'contexts': [
            'Personal loan EMI bounce charges: Rs.500 + applicable GST per bounce event. '
            'NACH mandate re-registration required after 3 consecutive bounces.'
        ],
        'ground_truth': 'The bounce charge for a personal loan EMI is Rs.500 + GST per bounce event.'
    },
    {
        'id': 'Q2',
        'question': 'What is the prepayment charge for closing a home loan early?',
        'answer': 'You can foreclose your home loan after 6 months. '
                  'The prepayment penalty is 2% of the outstanding amount.',
        'contexts': [
            'Home loan foreclosure allowed after 6 months. Prepayment charge: 4% on outstanding principal.',
            'Personal loan prepayment: allowed after 3 months. Penalty: 2% on principal.',
        ],
        'ground_truth': 'Home loan foreclosure allowed after 6 months. Prepayment charge is 4% on outstanding principal.'
    },
    {
        'id': 'Q3',
        'question': 'What is the FD interest rate for senior citizens at 24 months?',
        'answer': 'Bajaj Finance is a leading NBFC in India offering a wide range of financial '
                  'products including personal loans, home loans, and FDs across 3,000+ cities.',
        'contexts': [
            'Senior citizen FD rates: 8.35% p.a. (24M), 8.10% (12M). Additional 0.25% over regular rates.'
        ],
        'ground_truth': 'Senior citizens earn 8.35% p.a. on a 24-month FD - 0.25% higher than regular rates.'
    },
    {
        'id': 'Q4',
        'question': 'What documents are needed for a Bajaj personal loan?',
        'answer': 'For a Bajaj Finance personal loan, you need Aadhaar, PAN, last 3 months salary slips, '
                  'bank statements, property papers, and a builder NOC.',
        'contexts': [
            'Personal loan docs: Aadhaar, PAN, 3 months salary slips, bank statements.',
            'Home loan additional docs: property papers, NOC from builder, 6 months bank statements.',
        ],
        'ground_truth': 'Personal loan requires Aadhaar, PAN, 3 months salary slips, and bank statements.'
    },
    {
        'id': 'Q5',
        'question': 'What is the minimum investment for a Bajaj Finance FD?',
        'answer': 'The minimum investment for a Bajaj Finance FD is Rs.15,000. '
                  'Maximum is Rs.5 crore. Lock-in period is 3 months.',
        'contexts': [
            'Bajaj Finance FD: lock-in 3 months. Premature withdrawal: 2% penalty.'
            # investment limits chunk was NOT retrieved
        ],
        'ground_truth': 'Minimum investment is Rs.15,000. Maximum is Rs.5 crore. Lock-in: 3 months.'
    },
]

# %%
pip install ragas
# Out:
# ...
#   Using cached ragas-0.4.3-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached instructor-1.15.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached scikit_network-0.33.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.5 kB)
# ...
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached jiter-0.13.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...
#   Using cached rich-14.3.4-py3-none-any.whl.metadata (18 kB)
# ...
# Using cached ragas-0.4.3-py3-none-any.whl (466 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 8.2 MB/s  0:00:00
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached multiprocess-0.70.19-py313-none-any.whl (156 kB)
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from ragas.llms import llm_factory
from langchain_openai import ChatOpenAI
from ragas.metrics.collections import ContextPrecision
from openai import AsyncOpenAI
client = AsyncOpenAI()
llm = llm_factory("gpt-4o-mini",client=client)

# %%
score = ContextPrecision(llm)

# %%
user_input="What are the symptoms and causes of Type 2 diabetes?",
retrieved_contexts=[
    "Type 2 diabetes symptoms include frequent urination and excessive thirst.",
    "People with Type 2 diabetes often experience fatigue and blurred vision."
],
reference="Type 2 diabetes is caused by insulin resistance, " \
"often linked to obesity and a sedentary lifestyle." \
" Its symptoms include frequent urination, excessive thirst, " \
"fatigue, blurred vision, and slow-healing sores."

# %%
result =await score.ascore(
    user_input="What are the symptoms and causes of Type 2 diabetes?",
    retrieved_contexts=[
        "Type 2 diabetes symptoms include frequent urination and excessive thirst.",
        "People with Type 2 diabetes often experience fatigue and blurred vision."
    ],
    reference="Type 2 diabetes is caused by insulin resistance, often linked to obesity and a sedentary lifestyle. Its symptoms include frequent urination, excessive thirst, fatigue, blurred vision, and slow-healing sores."
)

# %%
result.value
# Out:
# 0.0
